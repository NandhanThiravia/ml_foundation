# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
movie_df = pd.read_csv('tmdb-movies.csv')

# %%
movie_df.shape
# Out:
# (10866, 21)

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# release_year            10866 non-null int64
# budget_adj              10866 non-null float64
# revenue_adj             10866 non-null float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %%
movie_df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# std      575.619058      0.935142     12.812941  3.430616e+07  1.446325e+08
# min       10.000000      1.500000   1960.000000  0.000000e+00  0.000000e+00
# 25%       17.000000      5.400000   1995.000000  0.000000e+00  0.000000e+00
# 50%       38.000000      6.000000   2006.000000  0.000000e+00  0.000000e+00
# 75%      145.750000      6.600000   2011.000000  2.085325e+07  3.369710e+07
# max     9767.000000      9.200000   2015.000000  4.250000e+08  2.827124e+09

# %%
movie_df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline      ...       \
# 0              The park is open.      ...
# 1             What a Lovely Day.      ...
# 2     One Choice Can Destroy You      ...
# 3  Every generation has a story.      ...
# 4            Vengeance Hits Home      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
stats = movie_df.groupby('release_year')['id'].count()

plt.figure(figsize=(12,6), dpi = 130)
plt.xlabel('Release Year of Movies', fontsize = 12)
plt.ylabel('Count of Movies', fontsize = 12)
plt.title('Representing Number of Movie releases Vs Year of their release.')

plt.plot(stats)

# %%
movie_df.drop(columns=['imdb_id', 'homepage', 'tagline', 'overview', 'budget_adj', 'revenue_adj'], axis=1, inplace=True)
movie_df.shape
# Out:
# (10866, 15)

# %%
movie_df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island      124
# 1   future|chase|post-apocalyptic|dystopia|australia      120
# 2  based on novel|revolution|dystopia|sequel|dyst...      119
# 3              android|spaceship|jedi|space opera|3d      136
# 4                car race|speed|revenge|suspense|car      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15        5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15        2947
#
#    vote_average  release_year
# 0           6.5          2015
# 1           7.1          2015
# 2           6.3          2015
# 3           7.5          2015
# 4           7.3          2015

# %%
movie_df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year
# count  10866.000000  10866.000000  10866.000000
# mean     217.389748      5.974922   2001.322658
# std      575.619058      0.935142     12.812941
# min       10.000000      1.500000   1960.000000
# 25%       17.000000      5.400000   1995.000000
# 50%       38.000000      6.000000   2006.000000
# 75%      145.750000      6.600000   2011.000000
# max     9767.000000      9.200000   2015.000000

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 15 columns):
# id                      10866 non-null int64
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# director                10822 non-null object
# keywords                9373 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# release_year            10866 non-null int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 1.2+ MB

# %%
movie_df[movie_df.cast.isna()].head()
# Out:
#          id  popularity  budget  revenue  \
# 371  345637    0.422901       0        0
# 441  355020    0.220751       0        0
# 465  321109    0.201696       0        0
# 536  333350    0.122543       0        0
# 538  224972    0.114264       0        0
#
#                                   original_title cast                director  \
# 371                          Sanjay's Super Team  NaN            Sanjay Patel
# 441  Winter on Fire: Ukraine's Fight for Freedom  NaN       Evgeny Afineevsky
# 465                                  Bitter Lake  NaN             Adam Curtis
# 536                               A Faster Horse  NaN              David Gelb
# 538                         The Mask You Live In  NaN  Jennifer Siebel Newsom
#
#                                               keywords  runtime       genres  \
# 371                                                NaN        7    Animation
# 441                                                NaN       98  Documentary
# 465             manipulation|politics|war|control|fear      135  Documentary
# 536  mustang|car|corporation|henry ford family|car ...       90  Documentary
# 538    feminism|sexism|young boy|gender roles|misogyny       88  Documentary
#
#                                   production_companies release_date  \
# 371                            Pixar Animation Studios     11/25/15
# 441  Passion Pictures|Campbell Grobman Films|Afinee...      10/9/15
# 465                                                BBC      1/24/15
# 536                                                NaN      10/8/15
# 538                                                NaN       1/1/15
#
#      vote_count  vote_average  release_year
# 371          47           6.9          2015
# 441          37           8.2          2015
# 465          19           7.8          2015
# 536          12           8.0          2015
# 538          11           8.9          2015

# %%
movie_df[movie_df.cast.isna()].count()
# Out:
# id                      76
# popularity              76
# budget                  76
# revenue                 76
# original_title          76
# cast                     0
# director                70
# keywords                45
# runtime                 76
# genres                  75
# production_companies    36
# release_date            76
# vote_count              76
# vote_average            76
# release_year            76
# dtype: int64

# %%
movie_df.dropna(subset = ['cast'], inplace=True)

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10790 entries, 0 to 10865
# Data columns (total 15 columns):
# id                      10790 non-null int64
# popularity              10790 non-null float64
# budget                  10790 non-null int64
# revenue                 10790 non-null int64
# original_title          10790 non-null object
# cast                    10790 non-null object
# director                10752 non-null object
# keywords                9328 non-null object
# runtime                 10790 non-null int64
# genres                  10768 non-null object
# production_companies    9800 non-null object
# release_date            10790 non-null object
# vote_count              10790 non-null int64
# vote_average            10790 non-null float64
# release_year            10790 non-null int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 1.3+ MB

# %%
movie_df[movie_df.director.isna()].head()
# Out:
#           id  popularity  budget  revenue  \
# 532   320996    0.126594       0        0
# 548   355131    0.108072       0        0
# 556   321160    0.100910       0        0
# 1032  259910    0.291253       0        0
# 1054  253675    0.269468       0        0
#
#                              original_title  \
# 532          Iliza Shlesinger: Freezing Hot
# 548              Sense8: Creating the World
# 556                          With This Ring
# 1032  Marvel Studios: Assembling a Universe
# 1054                     Unlocking Sherlock
#
#                                                    cast director  \
# 532                                    Iliza Shlesinger      NaN
# 548   Tuppence Middleton|Bae Doona |Brian J. Smith|A...      NaN
# 556   Regina Hall|Jill Scott|Eve|Brooklyn Sudano|Dei...      NaN
# 1032  Robert Downey Jr.|Chris Hemsworth|Chris Evans|...      NaN
# 1054  Benedict Cumberbatch|Martin Freeman|Steven Mof...      NaN
#
#                                                keywords  runtime  \
# 532   stand-up|stand up comedy|aftercreditsstinger|d...       71
# 548   sexuality|superhuman|superpower|making of|soci...       25
# 556                                             wedding      105
# 1032                superhero|marvel cinematic universe       43
# 1054                                                NaN       60
#
#                            genres  \
# 532                        Comedy
# 548   Documentary|Science Fiction
# 556                Comedy|Romance
# 1032         TV Movie|Documentary
# 1054         TV Movie|Documentary
#
#                               production_companies release_date  vote_count  \
# 532                         New Wave Entertainment      1/23/15          14
# 548                                        Netflix      8/10/15          12
# 556   Lifetime Television|Sony Pictures Television      1/24/15          14
# 1032                    Marvel Studios|ABC Studios      3/18/14          32
# 1054                                           NaN      1/19/14          11
#
#       vote_average  release_year
# 532            6.6          2015
# 548            7.5          2015
# 556            6.5          2015
# 1032           6.3          2014
# 1054           7.2          2014

# %%
movie_df.dropna(subset = ['cast', 'director', 'genres'], inplace=True)
movie_df.drop_duplicates(inplace=True)
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10731 entries, 0 to 10865
# Data columns (total 15 columns):
# id                      10731 non-null int64
# popularity              10731 non-null float64
# budget                  10731 non-null int64
# revenue                 10731 non-null int64
# original_title          10731 non-null object
# cast                    10731 non-null object
# director                10731 non-null object
# keywords                9306 non-null object
# runtime                 10731 non-null int64
# genres                  10731 non-null object
# production_companies    9772 non-null object
# release_date            10731 non-null object
# vote_count              10731 non-null int64
# vote_average            10731 non-null float64
# release_year            10731 non-null int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 1.3+ MB

# %%
movie_df.head(1)
# Out:
#        id  popularity     budget     revenue  original_title  \
# 0  135397   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island      124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
#
#    vote_average  release_year
# 0           6.5          2015

# %%
movie_df.query('budget==0').head()
# Out:
#         id  popularity  budget   revenue                  original_title  \
# 30  280996    3.927333       0  29355203                      Mr. Holmes
# 36  339527    3.358321       0  22354572                          Solace
# 72  284289    2.272044       0     45895                Beyond the Reach
# 74  347096    2.165433       0         0          Mythica: The Darkspore
# 75  308369    2.141506       0         0  Me and Earl and the Dying Girl
#
#                                                  cast  \
# 30  Ian McKellen|Milo Parker|Laura Linney|Hattie M...
# 36  Abbie Cornish|Jeffrey Dean Morgan|Colin Farrel...
# 72  Michael Douglas|Jeremy Irvine|Hanna Mangan Law...
# 74  Melanie Stone|Kevin Sorbo|Adam Johnson|Jake St...
# 75  Thomas Mann|RJ Cyler|Olivia Cooke|Connie Britt...
#
#                    director  \
# 30              Bill Condon
# 36            Afonso Poyart
# 72  Jean-Baptiste LÃ©onetti
# 74            Anne K. Black
# 75      Alfonso Gomez-Rejon
#
#                                              keywords  runtime  \
# 30                   london|detective|sherlock holmes      103
# 36  thriller|serial killer|psychic|fbi agent|intrigue      101
# 72                                     desert|hunting       95
# 74     sword|magic|sorcery|necromancer|woman director      108
# 75         tattoo|high school|leukemia|friends|parody      105
#
#                       genres  \
# 30             Mystery|Drama
# 36       Crime|Drama|Mystery
# 72                  Thriller
# 74  Action|Adventure|Fantasy
# 75              Comedy|Drama
#
#                                  production_companies release_date  \
# 30  BBC Films|See-Saw Films|FilmNation Entertainme...      6/19/15
# 36  Eden Rock Media|FilmNation Entertainment|Flynn...       9/3/15
# 72                                      Furthur Films      4/17/15
# 74                           Arrowstorm Entertainment      6/24/15
# 75                                  Indian Paintbrush      6/12/15
#
#     vote_count  vote_average  release_year
# 30         425           6.4          2015
# 36         474           6.2          2015
# 72          81           5.5          2015
# 74          27           5.1          2015
# 75         569           7.7          2015

# %%
movie_df.query('budget==0').groupby('budget').count()['id']
# Out:
# budget
# 0    5578
# Name: id, dtype: int64

# %%
movie_df['budget'].replace(0, np.NaN, inplace=True)
movie_df['revenue'].replace(0, np.NaN, inplace=True)
movie_df['runtime'].replace(0, np.NaN, inplace=True)

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10731 entries, 0 to 10865
# Data columns (total 15 columns):
# id                      10731 non-null int64
# popularity              10731 non-null float64
# budget                  5153 non-null float64
# revenue                 4843 non-null float64
# original_title          10731 non-null object
# cast                    10731 non-null object
# director                10731 non-null object
# keywords                9306 non-null object
# runtime                 10703 non-null float64
# genres                  10731 non-null object
# production_companies    9772 non-null object
# release_date            10731 non-null object
# vote_count              10731 non-null int64
# vote_average            10731 non-null float64
# release_year            10731 non-null int64
# dtypes: float64(5), int64(3), object(7)
# memory usage: 1.3+ MB

# %%
stats = movie_df.groupby('release_year')['id'].count()

# %%
plt.figure(figsize=(12,6), dpi = 130)
#on x-axis
plt.xlabel('Release Year of Movies', fontsize = 12)
#on y-axis
plt.ylabel('Count of Movies', fontsize = 12)
#title of the line plot
plt.title('Representing Number of Movie releases Vs Year of their release.')

plt.plot(stats)

# %%
def highest(column):
    index = movie_df[column].idxmax
    info = pd.DataFrame(movie_df.loc[index])
    return info

# %%
def lowest(column):
    index = movie_df[column].idxmin
    info = pd.DataFrame(movie_df.loc[index])
    return info

# %%
highest('budget')
# Out:
#                                                                    2244
# id                                                                46528
# popularity                                                      0.25054
# budget                                                         4.25e+08
# revenue                                                     1.10876e+07
# original_title                                        The Warrior's Way
# cast                  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...
# director                                                     Sngmoo Lee
# keywords              assassin|small town|revenge|deception|super speed
# runtime                                                             100
# genres                        Adventure|Fantasy|Action|Western|Thriller
# production_companies                           Boram Entertainment Inc.
# release_date                                                    12/2/10
# vote_count                                                           74
# vote_average                                                        6.4
# release_year                                                       2010

# %%
lowest('budget')
# Out:
#                                                                    1151
# id                                                               287524
# popularity                                                     0.177102
# budget                                                                1
# revenue                                                             NaN
# original_title                                              Fear Clinic
# cast                  Thomas Dekker|Robert Englund|Cleopatra Coleman...
# director                                                    Robert Hall
# keywords                                             phobia|doctor|fear
# runtime                                                              95
# genres                                                           Horror
# production_companies  Dry County Films|Anchor Bay Entertainment|Movi...
# release_date                                                   10/31/14
# vote_count                                                           15
# vote_average                                                        4.1
# release_year                                                       2014

# %%
movie_df.groupby('director')['id'].count()
# Out:
# director
#  FrÃ©dÃ©ric Jardin                                    1
# A. Todd Smith                                         1
# A.R. Murugadoss                                       1
# Aaron Aites                                           1
# Aaron Blaise|Robert Walker                            1
# Aaron Hann|Mario Miscione                             1
# Aaron Harvey                                          1
# Aaron Katz|Martha Stephens                            1
# Aaron Keeling|Austin Keeling                          1
# Aaron Moorhead|Justin Benson                          1
# Aaron Norris                                          5
# Aaron Schneider                                       1
# Aaron Seltzer|Jason Friedberg                         1
# Aaron Woodley                                         1
# Abbas Alibhai Burmawalla|Mastan Alibhai Burmawalla    2
# Abbas Kiarostami                                      2
# Abbas Tyrewala                                        1
# Abe Levy|Silver Tree                                  1
# Abe Sylvia                                            1
# Abel Ferrara                                          8
# Abel Ferry                                            1
# Adam Brooks                                           1
# Adam Brooks|Matthew Kennedy                           1
# Adam Curtis                                           2
# Adam Deacon|Daniel Toland                             1
# Adam Egypt Mortimer                                   1
# Adam Elliot                                           2
# Adam Fields                                           1
# Adam Gierasch                                         3
# Adam Green                                            4
#                                                      ..
# Zach Ingrasci|Sean Leonard|Chris Temple               1
# Zach Lipovsky                                         2
# Zachary Donohue                                       1
# Zachary Heinzerling                                   1
# Zachary Sluser                                        1
# Zack Parker                                           1
# Zack Snyder                                           6
# Zackary Adler                                         2
# Zak Hilditch                                          1
# Zak Knutson                                           1
# Zak Levitt                                            1
# Zak Penn                                              1
# Zal Batmanglij                                        2
# Zalman King                                           3
# Zana Briski|Ross Kauffman                             1
# Zatella Beatty                                        1
# Zeke Norton                                           2
# Zev Berman                                            1
# Zhao Lin-Shan                                         1
# Ziad Doueiri                                          1
# Zoe R. Cassavetes                                     1
# ÃdÃ¡m CsÃ¡szi                                         1
# Ãlex de la Iglesia                                    4
# Ãlvaro de ArmiÃ±Ã¡n                                   1
# Ã–zgÃ¼r Yildirim                                      1
# Ã‡aÄŸan Irmak                                         1
# Ã‰mile Gaudreault                                     1
# Ã‰ric Besnard                                         1
# Ã‰tienne Chatiliez                                    3
# Ã€lex Pastor|David Pastor                             1
# Name: id, Length: 5018, dtype: int64

# %%
all_casts = movie_df['cast'].str.cat(sep='|')

# %%
all_cast_series = pd.Series(all_casts.split('|'))

# %%
type(all_cast_series)
# Out:
# pandas.core.series.Series

# %%
movie_df.head()
# Out:
#        id  popularity       budget       revenue  \
# 0  135397   32.985763  150000000.0  1.513529e+09
# 1   76341   28.419936  150000000.0  3.784364e+08
# 2  262500   13.112507  110000000.0  2.952382e+08
# 3  140607   11.173104  200000000.0  2.068178e+09
# 4  168259    9.335014  190000000.0  1.506249e+09
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island    124.0
# 1   future|chase|post-apocalyptic|dystopia|australia    120.0
# 2  based on novel|revolution|dystopia|sequel|dyst...    119.0
# 3              android|spaceship|jedi|space opera|3d    136.0
# 4                car race|speed|revenge|suspense|car    137.0
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15        5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15        2947
#
#    vote_average  release_year
# 0           6.5          2015
# 1           7.1          2015
# 2           6.3          2015
# 3           7.5          2015
# 4           7.3          2015

# %%
def get_profitable_series(column):
    concat_str = movie_df[column].str.cat(sep='|')
    series = pd.Series(concat_str.split('|'))
    return series

# %%
def divide_quartile_segment(column, bin_names):
    series = movie_df[column].describe()
    bin_edges = [int(series['min']), int(series['25%']), int(series['50%']), int(series['75%']), int(series['max'])]
    movie_df['{}_levels'.format(column)] = pd.cut(movie_df[column], bin_edges, labels=bin_names, include_lowest = True)

# %% [markdown]
# ### Trial

# %%
def get_series(df, column):
    concat_str = df[column].str.cat(sep='|')
    series = pd.Series(concat_str.split('|'))
    return series

# %%
groupby_release_year = movie_df.groupby(['release_year'])

# %%
groupby_release_year_1960   = groupby_release_year.get_group(1960)
df = get_series(groupby_release_year_1960, 'genres').value_counts().reset_index()
df.head()
# Out:
#       index   0
# 0     Drama  13
# 1    Action   8
# 2    Comedy   8
# 3    Horror   7
# 4  Thriller   6

# %%
df.columns
# Out:
# Index(['index', 0], dtype='object')

# %%
df.rename(columns={'index':'genre', 0:'count'}, inplace=True)
df.head()
# Out:
#       genre  count
# 0     Drama     13
# 1    Action      8
# 2    Comedy      8
# 3    Horror      7
# 4  Thriller      6

# %%
groupby_release_year = movie_df.groupby(['release_year'])

# %%
main_df = pd.DataFrame(columns=['genre', 'count'])
main_df
# Out:
# Empty DataFrame
# Columns: [genre, count]
# Index: []

# %%
main_df = pd.DataFrame(columns=['genre', 'count'])
for name, group in groupby_release_year:
    df = get_series(groupby_release_year.get_group(name), 'genres').value_counts().reset_index()
    new_count_name = '{}_count'.format(name)
    df.rename(columns={'index':'genre', 0:new_count_name}, inplace=True)
    #print (df.head())
    main_df = main_df.merge(df, left_on='genre', right_on='genre', how='outer')
main_df.drop(columns=['count'], inplace=True)
main_df
# Out:
#               genre  1960_count  1961_count  1962_count  1963_count  \
# 0             Drama        13.0        16.0        21.0        13.0
# 1            Action         8.0         7.0         8.0         4.0
# 2            Comedy         8.0        10.0         5.0        13.0
# 3            Horror         7.0         3.0         5.0         9.0
# 4          Thriller         6.0         NaN         7.0        10.0
# 5           Romance         6.0         7.0         5.0         8.0
# 6           Western         6.0         3.0         3.0         2.0
# 7         Adventure         5.0         6.0         7.0         7.0
# 8           History         5.0         3.0         4.0         4.0
# 9   Science Fiction         3.0         4.0         2.0         2.0
# 10           Family         3.0         5.0         2.0         3.0
# 11          Fantasy         2.0         2.0         1.0         2.0
# 12              War         2.0         2.0         3.0         1.0
# 13            Crime         2.0         2.0         3.0         4.0
# 14          Foreign         1.0         1.0         1.0         2.0
# 15            Music         1.0         2.0         1.0         NaN
# 16        Animation         NaN         1.0         NaN         1.0
# 17          Mystery         NaN         1.0         4.0         6.0
# 18         TV Movie         NaN         NaN         NaN         NaN
# 19      Documentary         NaN         NaN         NaN         NaN
#
#     1964_count  1965_count  1966_count  1967_count  1968_count     ...      \
# 0         20.0        20.0        16.0        16.0        19.0     ...
# 1          5.0         9.0        14.0         7.0         6.0     ...
# 2         16.0         7.0        16.0        17.0         9.0     ...
# 3          6.0         5.0         3.0         4.0         4.0     ...
# 4          9.0        11.0         8.0         5.0         5.0     ...
# 5          9.0         5.0         6.0        11.0         6.0     ...
# 6          1.0         4.0         7.0         2.0         1.0     ...
# 7          5.0         6.0        11.0         7.0         5.0     ...
# 8          3.0         4.0         2.0         NaN         3.0     ...
# 9          4.0         2.0         6.0         4.0         4.0     ...
# 10         4.0         3.0         7.0         3.0         5.0     ...
# 11         4.0         NaN         2.0         3.0         5.0     ...
# 12         3.0         8.0         4.0         1.0         4.0     ...
# 13        10.0         2.0         5.0         7.0         5.0     ...
# 14         1.0         1.0         2.0         NaN         NaN     ...
# 15         5.0         2.0         NaN         4.0         3.0     ...
# 16         2.0         1.0         3.0         1.0         3.0     ...
# 17         4.0         3.0         6.0         3.0         4.0     ...
# 18         NaN         1.0         NaN         NaN         NaN     ...
# 19         NaN         NaN         1.0         1.0         NaN     ...
#
#     2006_count  2007_count  2008_count  2009_count  2010_count  2011_count  \
# 0          196         197         232       222.0         208         213
# 1           79          94          98       108.0         106         115
# 2          155         151         165       198.0         168         171
# 3           56          78          76        90.0          78          78
# 4          114         123         127       157.0         133         146
# 5           70          74          83        83.0          84          75
# 6            1           5           2         NaN           6           3
# 7           55          60          63        71.0          58          61
# 8           12          12          23        16.0          14           8
# 9           30          38          52        70.0          45          56
# 10          63          45          55        58.0          54          70
# 11          34          47          43        48.0          42          45
# 12           7           6          17        12.0           7           9
# 13          53          65          62        52.0          49          48
# 14          10          16          17        16.0          13          13
# 15          11          15          18        17.0           8          17
# 16          35          31          32        47.0          47          42
# 17          30          33          29        50.0          32          38
# 18           8           5           5         8.0           7          10
# 19          16          16          24        23.0          30          45
#
#     2012_count  2013_count  2014_count  2015_count
# 0          231       253.0       284.0       260.0
# 1           99       119.0       129.0       106.0
# 2          173       173.0       183.0       160.0
# 3          104       102.0       105.0       125.0
# 4          160       175.0       178.0       171.0
# 5           79        65.0        83.0        56.0
# 6            4         3.0         6.0         6.0
# 7           50        65.0        67.0        69.0
# 8           12        14.0        15.0        15.0
# 9           54        60.0        61.0        84.0
# 10          41        47.0        43.0        44.0
# 11          33        38.0        36.0        33.0
# 12          10         7.0        22.0         9.0
# 13          54        71.0        65.0        51.0
# 14           6         NaN         NaN         NaN
# 15          22        30.0        27.0        33.0
# 16          35        42.0        35.0        37.0
# 17          33        38.0        36.0        42.0
# 18          14         9.0        12.0        20.0
# 19          45        58.0        58.0        51.0
#
# [20 rows x 57 columns]

# %%
main_df.set_index('genre', inplace=True)
main_df.head()
# Out:
#           1960_count  1961_count  1962_count  1963_count  1964_count  \
# genre
# Drama           13.0        16.0        21.0        13.0        20.0
# Action           8.0         7.0         8.0         4.0         5.0
# Comedy           8.0        10.0         5.0        13.0        16.0
# Horror           7.0         3.0         5.0         9.0         6.0
# Thriller         6.0         NaN         7.0        10.0         9.0
#
#           1965_count  1966_count  1967_count  1968_count  1969_count  \
# genre
# Drama           20.0        16.0        16.0        19.0        13.0
# Action           9.0        14.0         7.0         6.0        10.0
# Comedy           7.0        16.0        17.0         9.0        11.0
# Horror           5.0         3.0         4.0         4.0         1.0
# Thriller        11.0         8.0         5.0         5.0         3.0
#
#              ...      2006_count  2007_count  2008_count  2009_count  \
# genre        ...
# Drama        ...             196         197         232       222.0
# Action       ...              79          94          98       108.0
# Comedy       ...             155         151         165       198.0
# Horror       ...              56          78          76        90.0
# Thriller     ...             114         123         127       157.0
#
#           2010_count  2011_count  2012_count  2013_count  2014_count  \
# genre
# Drama            208         213         231       253.0       284.0
# Action           106         115          99       119.0       129.0
# Comedy           168         171         173       173.0       183.0
# Horror            78          78         104       102.0       105.0
# Thriller         133         146         160       175.0       178.0
#
#           2015_count
# genre
# Drama          260.0
# Action         106.0
# Comedy         160.0
# Horror         125.0
# Thriller       171.0
#
# [5 rows x 56 columns]

# %%
main_df.loc['Drama']
# Out:
# 1960_count     13.0
# 1961_count     16.0
# 1962_count     21.0
# 1963_count     13.0
# 1964_count     20.0
# 1965_count     20.0
# 1966_count     16.0
# 1967_count     16.0
# 1968_count     19.0
# 1969_count     13.0
# 1970_count     19.0
# 1971_count     30.0
# 1972_count     16.0
# 1973_count     31.0
# 1974_count     21.0
# 1975_count     17.0
# 1976_count     22.0
# 1977_count     23.0
# 1978_count     29.0
# 1979_count     30.0
# 1980_count     32.0
# 1981_count     32.0
# 1982_count     33.0
# 1983_count     35.0
# 1984_count     40.0
# 1985_count     39.0
# 1986_count     51.0
# 1987_count     52.0
# 1988_count     53.0
# 1989_count     54.0
# 1990_count     60.0
# 1991_count     63.0
# 1992_count     65.0
# 1993_count     90.0
# 1994_count     83.0
# 1995_count     93.0
# 1996_count    104.0
# 1997_count     83.0
# 1998_count    108.0
# 1999_count    113.0
# 2000_count    100.0
# 2001_count    100.0
# 2002_count    129.0
# 2003_count    110.0
# 2004_count    141.0
# 2005_count    182.0
# 2006_count    196.0
# 2007_count    197.0
# 2008_count    232.0
# 2009_count    222.0
# 2010_count    208.0
# 2011_count    213.0
# 2012_count    231.0
# 2013_count    253.0
# 2014_count    284.0
# 2015_count    260.0
# Name: Drama, dtype: float64
