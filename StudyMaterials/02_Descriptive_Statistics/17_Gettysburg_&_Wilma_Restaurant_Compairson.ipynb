# %%
import pandas as pd

# %%
restaurant_comparison_df = pd.read_excel("17_Gettysburg_&_Wilma_Restaurant_Compairson.xlsx", usecols=[0,1])
restaurant_comparison_df
# Out:
#     Average meal prices at restaurants in Gettysburg ($)  \
# 0                                                   9
# 1                                                   5
# 2                                                   6
# 3                                                  11
# 4                                                   8
# 5                                                   5
# 6                                                   7
# 7                                                  13
# 8                                                  12
# 9                                                  13
# 10                                                  9
# 11                                                  8
# 12                                                 10
# 13                                                  6
# 14                                                 11
# 15                                                  9
# ...

# %%
restaurant_comparison_df.describe()
# Out:
#        Average meal prices at restaurants in Gettysburg ($)  \
# count                                          18.000000
# mean                                            8.944444
# std                                             2.645134
# min                                             5.000000
# 25%                                             7.000000
# 50%                                             9.000000
# 75%                                            11.000000
# max                                            13.000000
#
#        Average meal prices at restaurants in Wilma ($)
# count                                        14.000000
# mean                                         11.142857
# std                                           2.178819
# min                                           8.000000
# 25%                                           9.250000
# 50%                                          11.000000
# 75%                                          12.750000
# ...
