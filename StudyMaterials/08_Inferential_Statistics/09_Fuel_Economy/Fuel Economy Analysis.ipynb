# %%
import numpy as np
import pandas as pd

df_08 = pd.read_csv('08tstcar.csv')
df_08.describe()
# Out:
#        MDLYR_DT    VI_MFR_CD  GBE_INDX_NUM  VC_CNFG_NUM  GBE_CID_MSR  \
# count    3015.0  3015.000000   3015.000000  3015.000000  3015.000000
# mean     2008.0   293.447761    218.003648     2.025871   216.903151
# std         0.0   327.347348    311.115640     3.594676    77.526179
# min      2008.0    20.000000      1.000000     0.000000    61.000000
# 25%      2008.0    40.000000     17.000000     0.000000   150.000000
# 50%      2008.0   220.000000     35.000000     1.000000   211.000000
# 75%      2008.0   560.000000    300.000000     3.000000   280.000000
# max      2008.0  5385.000000    971.000000    40.000000   511.000000
#
#        VC_RTD_HP_MSR  ECS_CD  ECS_CD_0  ECS_CD_1  ECS_CD_2        ...          \
# count    3015.000000     0.0       0.0       0.0       0.0        ...
# mean      262.233831     NaN       NaN       NaN       NaN        ...
# std       108.444519     NaN       NaN       NaN       NaN        ...
# ...

# %%
df_18 = pd.read_csv('18tstcar-2018-10-24.xlsx')
df_18.describe()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-807cfbb75e6d> in <module>
# ----> 1 df_18 = pd.read_csv('18tstcar-2018-10-24.xlsx')
#       2 df_18.describe()
#
# C:\Tools\MachineLearning\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...
