# %%
import pandas as pd

# %%
goog_stock = pd.read_csv('goog-1.csv')

# %%
goog_stock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19   49.676899   51.693783   47.669952   49.845802   49.845802
# 1     2004-08-20   50.178635   54.187561   49.925285   53.805050   53.805050
# 2     2004-08-23   55.017166   56.373344   54.172661   54.346527   54.346527
# 3     2004-08-24   55.260582   55.439419   51.450363   52.096165   52.096165
# 4     2004-08-25   52.140873   53.651051   51.604362   52.657513   52.657513
# ...          ...         ...         ...         ...         ...         ...
# 3308  2017-10-09  980.000000  985.424988  976.109985  977.000000  977.000000
# 3309  2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#         Volume
# 0     44994500
# ...

# %%
goog_stock.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 1  2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2  2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 3  2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 4  2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
goog_stock.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3308  2017-10-09  980.000000  985.424988  976.109985  977.000000  977.000000
# 3309  2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#        Volume
# 3308   891400
# 3309   968400
# 3310  1693300
# 3311  1262400
# 3312  1157700

# %%
goog_stock.set_index('Date')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-08-19   49.676899   51.693783   47.669952   49.845802   49.845802
# 2004-08-20   50.178635   54.187561   49.925285   53.805050   53.805050
# 2004-08-23   55.017166   56.373344   54.172661   54.346527   54.346527
# 2004-08-24   55.260582   55.439419   51.450363   52.096165   52.096165
# 2004-08-25   52.140873   53.651051   51.604362   52.657513   52.657513
# ...                ...         ...         ...         ...         ...
# 2017-10-09  980.000000  985.424988  976.109985  977.000000  977.000000
# 2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#               Volume
# Date
# 2004-08-19  44994500
# 2004-08-20  23005800
# 2004-08-23  18393200
# ...

# %%
# Check how many NaN values are there
goog_stock.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Check if any columns have NaN values
goog_stock.isnull().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
goog_stock.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3313.000000  3313.000000  3313.000000  3313.000000  3313.000000
# mean    380.186092   383.493740   376.519309   380.072458   380.072458
# std     223.818650   224.974534   222.473232   223.853780   223.853780
# min      49.274517    50.541279    47.669952    49.681866    49.681866
# 25%     226.556473   228.394516   224.003082   226.407440   226.407440
# 50%     293.312286   295.433502   289.929291   293.029114   293.029114
# 75%     536.650024   540.000000   532.409973   536.690002   536.690002
# max     992.000000   997.210022   989.000000   989.679993   989.679993
#
#              Volume
# count  3.313000e+03
# mean   8.038476e+06
# std    8.399521e+06
# min    7.900000e+03
# 25%    2.584900e+06
# 50%    5.281300e+06
# 75%    1.065370e+07
# max    8.276810e+07

# %%
goog_stock['Adj Close'].describe()
# Out:
# count    3313.000000
# mean      380.072458
# std       223.853780
# min        49.681866
# 25%       226.407440
# 50%       293.029114
# 75%       536.690002
# max       989.679993
# Name: Adj Close, dtype: float64

# %%
goog_stock['Adj Close'].mean()
# Out:
# 380.0724580579537

# %%
goog_stock['High'].max()
# Out:
# 997.210022

# %%
goog_stock.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999904  0.999845  0.999745   0.999745 -0.564258
# High       0.999904  1.000000  0.999834  0.999868   0.999868 -0.562749
# Low        0.999845  0.999834  1.000000  0.999899   0.999899 -0.567007
# Close      0.999745  0.999868  0.999899  1.000000   1.000000 -0.564967
# Adj Close  0.999745  0.999868  0.999899  1.000000   1.000000 -0.564967
# Volume    -0.564258 -0.562749 -0.567007 -0.564967  -0.564967  1.000000

# %% [markdown]
# #### Fake Company data

# %%
fake_company = pd.read_csv('fake-company.csv')
fake_company
# Out:
#    Year     Name Department  Age  Salary
# 0  1990    Alice         HR   25   50000
# 1  1990      Bob         RD   30   48000
# 2  1990  Charlie      Admin   45   55000
# 3  1991   Dakota         HR   26   52000
# 4  1991     Elsa         RD   31   50000
# 5  1991    Frank      Admin   46   60000
# 6  1992    Grace      Admin   27   60000
# 7  1992  Hoffman         RD   32   52000
# 8  1992    Inaar      Admin   28   62000

# %%
fake_company.size
# Out:
# 45

# %%
# Year-wise company spent on salary
fake_company.groupby(['Year'])['Salary'].sum()
# Out:
# Year
# 1990    153000
# 1991    162000
# 1992    174000
# Name: Salary, dtype: int64

# %%
# Average salary every year
fake_company.groupby(['Year'])['Salary'].mean()
# Out:
# Year
# 1990    51000.0
# 1991    54000.0
# 1992    58000.0
# Name: Salary, dtype: float64

# %%
# Salary distribution based on company
fake_company.groupby(['Department', 'Year'])['Salary'].sum()
# Out:
# Department  Year
# Admin       1990     55000
#             1991     60000
#             1992    122000
# HR          1990     50000
#             1991     52000
# RD          1990     48000
#             1991     50000
#             1992     52000
# Name: Salary, dtype: int64

# %%
fake_company.groupby(['Department'])['Age'].describe()
# Out:
#             count  mean        std   min    25%   50%    75%   max
# Department
# Admin         4.0  36.5  10.408330  27.0  27.75  36.5  45.25  46.0
# HR            2.0  25.5   0.707107  25.0  25.25  25.5  25.75  26.0
# RD            3.0  31.0   1.000000  30.0  30.50  31.0  31.50  32.0
